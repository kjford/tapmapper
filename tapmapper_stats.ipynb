# %%
import similaritymat
import pymysql as mdb
from authent import dbauth as authsql
import pandas as pd

# import data from database
con=mdb.connect(**authsql)
tfidfDF=similaritymat.readTFIDF(con)

# %%
print tfidfDF
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8194 entries, 0 to 8193
# Data columns (total 3 columns):
# beerid      8194  non-null values
# locbinid    8194  non-null values
# TFIDF       8194  non-null values
# dtypes: float64(1), int64(2)

# %%
simmat=similaritymat.makeSimMat(tfidfDF)

# %%
imshow(simmat[0])

# %%
distmat=1.-simmat[0]

# %%
from scipy.cluster import hierarchy
from scipy.spatial.distance import squareform
distmat[np.eye(distmat.shape[0])==1]=0
clust=hierarchy.linkage(squareform(distmat),metric="precomputed")

# %%
hierarchy.dendrogram(clust)
# Out:
# {'color_list': ['b',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
#   'g',
#   'b',
#   'b',
#   'b',
#   'b',
#   'r',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
#   'c',
#   'c',
#   'b',
#   'm',
#   'y',
#   'b',
#   'b',
#   'b',
#   'k',
#   'b',
#   'g',
#   'r',
#   'r',
#   'b',
#   'b',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
#   'b',
# ...

# %%
reload(tweetsvstime)
dayrun14=tweetsvstime.hourly(hrbin=6,ndays=14)

# %%
reload(tweetsvstime)
snob=tweetsvstime.beersnob()

# %%
snob.sort('snobscore')
# Out:
#     locbinid  cityid  beercount           fullname        lat         lng  snobscore
# 4         37   13704         55     Louisville, KY  38.222539  -85.731388  15.796215
# 2         39   12851         54      Las Vegas, NV  36.148491 -115.173969  16.144965
# 3         38   17305         55          Omaha, NE  41.257774  -96.033224  16.327183
# 0         40   20598         53    San Antonio, TX  29.465545  -98.529230  16.755273
# 11        30   14995         82          Miami, FL  25.779705  -80.281183  16.819616
# 6         35    4510         62     Cincinnati, OH  39.143976  -84.512044  16.819669
# 10        31    5066         78       Columbus, OH  39.980620  -82.988567  17.495683
# 19        22   19840        105      Rochester, NY  43.170996  -77.620173  17.588262
# 22        19    5806        119         Dallas, TX  32.801113  -96.791232  17.688958
# 20        21    3004        106       Brooklyn, NY  40.653290  -73.957097  17.784129
# ...

# %%
snob.hist('snobscore')
# Out:
# array([[<matplotlib.axes.AxesSubplot object at 0x111a77690>]], dtype=object)
